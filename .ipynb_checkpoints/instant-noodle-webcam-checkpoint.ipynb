# %% [markdown]
# ## WebCam
# ### 반드시 local jupyter notebook에서 실행해주세요
# torch version: torch 1.8.0 이상
# 종료시: 작업관리자 - python - 작업끝내기

# %%
# pytorch version check - 1.8.0+ available
import torch

print(torch.__version__)
# Out:
# 1.8.2

# %%
# %cd ./instant-noodle/yolov5
# Out:
# C:\Users\yoolim\Documents\GitHub\Team3-withUs\instant-noodle\yolov5

# %%
weights_path = 'C:\\Users\\yoolim\\Documents\\GitHub\\Team3-withUs\\instant-noodle\\yolov5\\runs\\train\\noodle-result5\\weights\\best.pt'

# model run with webcam
# !python detect.py --weights "{weights_path}" --img 416 --conf 0.5 --source 0
# Out:
# detect: weights=['C:\\Users\\yoolim\\Documents\\GitHub\\Team3-withUs\\instant-noodle\\yolov5\\runs\\train\\noodle-result5\\weights\\best.pt'], source=0, data=data\coco128.yaml, imgsz=[416, 416], conf_thres=0.5, iou_thres=0.45, max_det=1000, device=, view_img=False, save_txt=False, save_conf=False, save_crop=False, nosave=False, classes=None, agnostic_nms=False, augment=False, visualize=False, update=False, project=runs\detect, name=exp, exist_ok=False, line_thickness=3, hide_labels=False, hide_conf=False, half=False, dnn=False
# YOLOv5  v6.2-61-gffbce38 Python-3.7.13 torch-1.8.2 CUDA:0 (NVIDIA GeForce RTX 3080, 10240MiB)
#
# Fusing layers...
# YOLOv5s summary: 213 layers, 7228582 parameters, 0 gradients, 16.4 GFLOPs
# 1/1: 0...  Success (inf frames 640x480 at 30.00 FPS)
#
# 0: 320x416 (no detections), 71.8ms
# 0: 320x416 (no detections), 5.0ms
# 0: 320x416 (no detections), 4.9ms
# 0: 320x416 (no detections), 5.0ms
# 0: 320x416 (no detections), 6.0ms
# ...
